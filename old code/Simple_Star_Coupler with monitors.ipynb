# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd


# FDTD Library is open source MEEP
# https://meep.readthedocs.io/en/latest/

import meep as mp
#from meep.materials import SiO2, Si

# %matplotlib widget

# %% [markdown]
# ### Simulation Settings

# %%
# To understand MEEP units see https://meep.readthedocs.io/en/latest/Introduction/#units-in-meep
wavelength = 1.55 # wavelength can have arbitrary length units (we choose um)
f = 1/wavelength # Frequency is defined in "natural units" as (1 um)/wavelength

l,w,z = [60,30,0] # length,width,height of the simulation region (um)



r = 30 # Star Coupler Radius (um)
h = 25 # Star Coupler Height (um) (this gives the flat top/bottom if desired)

waveguide_width = 0.5 # width of Si waveguide (um)
nguides_p = 10 # number of input waveguides above center (total numper is 2*nguides_p+1)
nangles = np.arange(-nguides_p,nguides_p+1,1) 

amplitudes = np.ones(len(nangles),dtype=complex) # amplitude/phase shift for each sources

## For tilted input
# amplitudes = np.zeros(len(nangles),dtype=complex) # amplitude/phase shift for each sources
# dl = 2*np.pi/len(nangles)
# for n in range(len(nangles)):
#     amplitudes[n]=np.exp(-1j*n)


y_guide_size = 1 # width of eigenmode source (needs to enclose waveguide)
dr = 10 # srces are placed at distance r+dr from confocal point

neff = 2.44 # Effective slab index from Lumerical simulation
#neff = 2.85

res = 80 # sim resolution (pixels/um)

# %% [markdown]
# ### Create simulation region and define media

# %%
# Define Simulation Cell
# All length units are microns
cell = mp.Vector3(l,w,z)

si = mp.Medium(epsilon=12)
sio2 = mp.Medium(index=1.444)

# %% [markdown]
# ### Create Starcoupler Region as MP Material Grid

# %%
x = np.arange(-r,r,1/res)
y = np.arange(-1.5*h/2,1.5*h/2,1/res)
xx,yy = np.meshgrid(x,y)


c1 = ((xx-r/2)**2 + yy**2 < r**2) # First circle with radius r
c2 = ((xx+r/2)**2 + yy**2 < r**2) # Second circle with radius r
b = (yy<h/2) & (yy>-h/2) # Rectangle allowing top/bottom cutoff

sc = c1 & c2 & b # star coupler shape comes from logical-AND all 3 shapes

star_grid = mp.MaterialGrid([len(x),len(y),0],
                           medium1 = sio2,
                           medium2 = si,
                           weights = sc.transpose())

star_block = mp.Block(size=mp.Vector3(x[-1]-x[0],y[-1]-y[0],0),material=star_grid)

# %% [markdown]
# ### Create Input and Output Waveguides

# %%
rot_angles = [np.arcsin(i*np.sqrt((1.55)/(r*len(nangles)*neff))) for i in nangles]

def make_waveguide(th,l,r):
    wg = mp.Block(mp.Vector3(np.abs(l),waveguide_width,mp.inf),
                     center=mp.Vector3(0,0),
                     e1=mp.Vector3(x=1).rotate(mp.Vector3(z=1), th),
                     e2=mp.Vector3(y=1).rotate(mp.Vector3(z=1), th),
                     material=si)
    
    wg = wg.shift(mp.Vector3(x=r/2-l*np.cos(th)/2,y=-l*np.sin(th)/2))
    # wg += mp.Vector3(r/2,0,0)
    # wg = wg.shift(mp.Vector3(x=l*np.cos(th)/2,y=-l*np.sin(th)/2))
    # wg += mp.Vector3(-l,0,0)

    # wg = wg.shift(mp.Vector3(x=10,y=0))

    return wg

input_waveguides = [make_waveguide(th,l,r) for th in rot_angles]
output_waveguides = [make_waveguide(th,-l,-r) for th in rot_angles]

# %% [markdown]
# ### Add Eigenmode Sources

# %%
def wg_eig_src(r,dr,th,ysize=1,freq=f,bd=1,amp=1.0):
    eig_src = mp.EigenModeSource(src=mp.ContinuousSource(frequency=freq),
                                 size=mp.Vector3(y=ysize),
                                 direction=mp.NO_DIRECTION,
                                 eig_kpoint=mp.Vector3(x=1).rotate(mp.Vector3(z=1),-th),
                                 center=mp.Vector3(-(r+dr)*np.cos(th)+r/2,(r+dr)*np.sin(th),0),
                                 eig_band = bd,
                                 eig_parity=mp.ODD_Z,
                                 eig_match_freq=True,
                                 amplitude=amp)
    return eig_src

n = 3.464 #index of refraction for si waveguide


def wg_eig_src_guassian(r,dr,th,ysize=1,freq=f,bd=1,amp=1.0):
    k_point = mp.Vector3(f * n).rotate(mp.Vector3(z=1), -th)
    print("th: ", th)

    eig_src = mp.EigenModeSource(
        src=mp.GaussianSource(freq,fwidth=0.2*freq, width=2),
        size=mp.Vector3(y=ysize),
        direction=mp.NO_DIRECTION,
        eig_kpoint=k_point,
        center=mp.Vector3(-(r+dr)*np.cos(th)+r/2,(r+dr)*np.sin(th),0),
        eig_band = bd,
        eig_parity=mp.ODD_Z,
        eig_match_freq=True,
        amplitude=amp
        )
    return eig_src


# Adds an eigenmode source for each input waveguide -- can get a source's amplitude to 0 to turn it off
# bottom 1/2
# sources = [wg_eig_src(r,dr,s,ysize=y_guide_size,amp=a) for (s,a) in zip(rot_angles[0:int((len(rot_angles)-1)/2)],amplitudes[0:int((len(rot_angles)-1)/2)])]

# full
sources = [wg_eig_src_guassian(r,6,s,ysize=y_guide_size,amp=a) for (s,a) in zip(rot_angles,amplitudes)]

#just 8 and 12
# sources = [wg_eig_src_guassian(r,dr,rot_angles[7],ysize=y_guide_size,amp=amplitudes[7]), wg_eig_src_guassian(r,dr,rot_angles[11],ysize=y_guide_size,amp=amplitudes[11])]
# Out:
# th:  -0.32313580228792316
# th:  -0.2898280609688875
# th:  -0.2568480830417025
# th:  -0.22415146665737368
# th:  -0.1916968887745476
# th:  -0.15944554785015785
# th:  -0.12736068452322252
# th:  -0.09540716229630482
# th:  -0.06355109384837095
# th:  -0.0317595012246263
# th:  0.0
# th:  0.0317595012246263
# th:  0.06355109384837095
# th:  0.09540716229630482
# th:  0.12736068452322252
# th:  0.15944554785015785
# th:  0.1916968887745476
# th:  0.22415146665737368
# th:  0.2568480830417025
# th:  0.2898280609688875
# th:  0.32313580228792316

# %% [markdown]
# ### Create Simulation Object

# %%
sim = mp.Simulation(resolution = res,
                    cell_size = cell,
                    default_material=sio2,
                    geometry = [star_block] + output_waveguides + input_waveguides,
                    sources=sources,
                    boundary_layers=[mp.PML(2.0)],
                    symmetries=[])

# %% [markdown]
# ### Add Mode Monitors

# %%
# def create_monitor(r,dr,th,ysize=1):
#     flux = sim.add_mode_monitor(f, 0, 1, 
#                             mp.ModeRegion(mp.Vector3(-(r+dr)*np.cos(th)+r/2,(r+dr)*np.sin(th),0),size=mp.Vector3(y=ysize)), 
#                             decimation_factor=0,
#                             direction=mp.NO_DIRECTION
#                             # eig_kpoint=mp.Vector3(x=1).rotate(mp.Vector3(z=1),-th)
#                             )
#     return flux

def create_monitor(r,dr,th,ysize=1):
    flux = sim.add_mode_monitor(f, 0, 1, 
                            mp.ModeRegion(mp.Vector3(-(r+dr)*np.cos(th)+r/2,(r+dr)*np.sin(th),0),size=mp.Vector3(y=ysize)), 
                            decimation_factor=0,
                            direction=mp.NO_DIRECTION,
                            eig_kpoint=mp.Vector3(x=1).rotate(mp.Vector3(z=1),-th)
                            )
    return flux


#  top half left side
# monitors = [create_monitor(r-1,dr,s,ysize=y_guide_size) for (s,a) in zip(rot_angles[int((len(rot_angles)-1)/2):len(rot_angles)],amplitudes[int((len(rot_angles)-1)/2):len(rot_angles)])]
print("dr: ", dr)
# all left side
# input_monitors = [create_monitor(r-5,dr,s,ysize=y_guide_size) for (s,a) in zip(rot_angles,amplitudes)]
output_monitors = [create_monitor(-r,-3,s,ysize=y_guide_size) for (s,a) in zip(rot_angles,amplitudes)]
print("r: ", r)
print("dr: ", dr)
# output_monitors = [create_monitor(-r+5,-dr,s,ysize=y_guide_size) for (s,a) in zip(rot_angles,amplitudes)]
input_monitors = [create_monitor(r,3,s,ysize=y_guide_size) for (s,a) in zip(rot_angles,amplitudes)]
# Out:
# dr:  10
# r:  30
# dr:  10

# %% [markdown]
# ### Initialize Simulation

# %%
# Separating the initialization call from the run call allows the option of viewing the simulation geometry/index before running the simulation
sim.init_sim()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00263214 s
# Working in 2D dimensions.
# Computational cell is 60 x 30 x 0 with resolution 80
#      block, center = (0,0,0)
#           size (59.9875,37.4875,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (13.4473,-9.52625,0)
#           size (60,0.5,1e+20)
#           axes (0.948244,-0.317542,0), (0.317542,0.948244,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (13.7488,-8.57362,0)
#           size (60,0.5,1e+20)
#           axes (0.958293,-0.285787,0), (0.285787,0.958293,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.0159,-7.621,0)
#           size (60,0.5,1e+20)
#           axes (0.967195,-0.254033,0), (0.254033,0.967195,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.2495,-6.66837,0)
#           size (60,0.5,1e+20)
#           axes (0.974983,-0.222279,0), (0.222279,0.974983,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.4505,-5.71575,0)
#           size (60,0.5,1e+20)
#           axes (0.981682,-0.190525,0), (0.190525,0.981682,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.6195,-4.76312,0)
#           size (60,0.5,1e+20)
#           axes (0.987315,-0.158771,0), (0.158771,0.987315,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.757,-3.8105,0)
#           size (60,0.5,1e+20)
#           axes (0.991901,-0.127017,0), (0.127017,0.991901,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.8636,-2.85787,0)
#           size (60,0.5,1e+20)
#           axes (0.995452,-0.0952625,0), (0.0952625,0.995452,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.9394,-1.90525,0)
#           size (60,0.5,1e+20)
#           axes (0.997981,-0.0635083,0), (0.0635083,0.997981,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      ...(+ 33 objects not shown)...
# subpixel-averaging is 78.2801% done, 1.11021 s remaining
# subpixel-averaging is 79.2448% done, 1.04788 s remaining
# subpixel-averaging is 7.44213% done, 49.7643 s remaining
# subpixel-averaging is 15.2816% done, 22.1886 s remaining
# subpixel-averaging is 23.1211% done, 13.3102 s remaining
# subpixel-averaging is 28.1899% done, 10.1944 s remaining
# subpixel-averaging is 33.699% done, 7.88543 s remaining
# subpixel-averaging is 39.3263% done, 6.17968 s remaining
# subpixel-averaging is 45.0394% done, 4.88721 s remaining
# subpixel-averaging is 50.5378% done, 3.92073 s remaining
# subpixel-averaging is 55.9825% done, 3.14915 s remaining
# subpixel-averaging is 61.5345% done, 2.50271 s remaining
# subpixel-averaging is 66.7644% done, 1.99171 s remaining
# subpixel-averaging is 71.6722% done, 1.58353 s remaining
# subpixel-averaging is 76.3436% done, 1.24042 s remaining
# subpixel-averaging is 83.528% done, 0.789433 s remaining
# subpixel-averaging is 91.0239% done, 0.394585 s remaining
# subpixel-averaging is 98.2942% done, 0.0695237 s remaining
# subpixel-averaging is 79.9339% done, 1.0052 s remaining
# subpixel-averaging is 71.2514% done, 1.61479 s remaining
# subpixel-averaging is 6.99109% done, 53.2202 s remaining
# subpixel-averaging is 14.7447% done, 23.1573 s remaining
# subpixel-averaging is 22.6915% done, 13.6316 s remaining
# subpixel-averaging is 28.0181% done, 10.2806 s remaining
# subpixel-averaging is 33.452% done, 7.9576 s remaining
# subpixel-averaging is 39.1652% done, 6.21745 s remaining
# subpixel-averaging is 44.8569% done, 4.92995 s remaining
# subpixel-averaging is 50.3552% done, 3.94625 s remaining
# subpixel-averaging is 55.7784% done, 3.17515 s remaining
# subpixel-averaging is 61.2983% done, 2.52714 s remaining
# subpixel-averaging is 66.453% done, 2.02033 s remaining
# subpixel-averaging is 71.3822% done, 1.60521 s remaining
# subpixel-averaging is 75.957% done, 1.26721 s remaining
# subpixel-averaging is 82.7763% done, 0.832339 s remaining
# subpixel-averaging is 90.3366% done, 0.428313 s remaining
# subpixel-averaging is 97.521% done, 0.101696 s remaining
# subpixel-averaging is 77.0398% done, 1.19368 s remaining
# subpixel-averaging is 78.2801% done, 1.11011 s remaining
# subpixel-averaging is 7.40991% done, 50.0576 s remaining
# subpixel-averaging is 15.0453% done, 22.596 s remaining
# subpixel-averaging is 22.713% done, 13.6219 s remaining
# subpixel-averaging is 28.0503% done, 10.2765 s remaining
# subpixel-averaging is 33.495% done, 7.94322 s remaining
# subpixel-averaging is 39.2189% done, 6.20251 s remaining
# subpixel-averaging is 44.9642% done, 4.90298 s remaining
# subpixel-averaging is 50.4948% done, 3.92472 s remaining
# subpixel-averaging is 55.9932% done, 3.14663 s remaining
# subpixel-averaging is 61.5345% done, 2.50407 s remaining
# subpixel-averaging is 66.8718% done, 1.98515 s remaining
# subpixel-averaging is 71.8118% done, 1.57127 s remaining
# subpixel-averaging is 76.4725% done, 1.23214 s remaining
# subpixel-averaging is 83.8073% done, 0.773171 s remaining
# subpixel-averaging is 91.2387% done, 0.384118 s remaining
# subpixel-averaging is 98.4123% done, 0.064576 s remaining
# time for set_epsilon = 238.031 s
# -----------
# MPB solved for frequency_1(2.11917,0.709654,0) = 0.682815 after 16 iters
# MPB solved for frequency_1(1.99182,0.667008,0) = 0.64518 after 8 iters
# MPB solved for frequency_1(1.99176,0.666987,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.14163,0.638689,0) = 0.683719 after 16 iters
# MPB solved for frequency_1(2.00977,0.599365,0) = 0.645182 after 9 iters
# MPB solved for frequency_1(2.0097,0.599344,0) = 0.645161 after 4 iters
# MPB solved for frequency_1(2.16153,0.567723,0) = 0.683055 after 16 iters
# MPB solved for frequency_1(2.03077,0.53338,0) = 0.645182 after 9 iters
# MPB solved for frequency_1(2.0307,0.533362,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.17893,0.496758,0) = 0.682914 after 15 iters
# MPB solved for frequency_1(2.04761,0.466819,0) = 0.645182 after 8 iters
# MPB solved for frequency_1(2.04753,0.466802,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.1939,0.425793,0) = 0.682554 after 15 iters
# MPB solved for frequency_1(2.06295,0.400378,0) = 0.645182 after 9 iters
# MPB solved for frequency_1(2.06288,0.400364,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.20649,0.354827,0) = 0.683319 after 14 iters
# MPB solved for frequency_1(2.07205,0.333207,0) = 0.645183 after 8 iters
# MPB solved for frequency_1(2.07197,0.333195,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.07197,0.333195,0) = 0.645161 after 1 iters
# MPB solved for frequency_1(2.21674,0.283862,0) = 0.682887 after 14 iters
# MPB solved for frequency_1(2.08322,0.266765,0) = 0.645183 after 8 iters
# MPB solved for frequency_1(2.08315,0.266755,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.08315,0.266755,0) = 0.645161 after 1 iters
# MPB solved for frequency_1(2.22468,0.212896,0) = 0.683159 after 15 iters
# MPB solved for frequency_1(2.08969,0.199978,0) = 0.645184 after 9 iters
# MPB solved for frequency_1(2.08961,0.19997,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.08961,0.19997,0) = 0.645161 after 1 iters
# MPB solved for frequency_1(2.23033,0.141931,0) = 0.682951 after 16 iters
# MPB solved for frequency_1(2.09575,0.133367,0) = 0.645184 after 9 iters
# MPB solved for frequency_1(2.09567,0.133362,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.09567,0.133362,0) = 0.645161 after 1 iters
# MPB solved for frequency_1(2.23371,0.0709654,0) = 0.682761 after 16 iters
# MPB solved for frequency_1(2.09961,0.0667051,0) = 0.645184 after 9 iters
# MPB solved for frequency_1(2.09953,0.0667026,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.09953,0.0667026,0) = 0.645161 after 1 iters
# MPB solved for frequency_1(2.23484,0,0) = 0.681169 after 15 iters
# MPB solved for frequency_1(2.10645,0,0) = 0.645182 after 7 iters
# MPB solved for frequency_1(2.10638,0,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.23371,-0.0709654,0) = 0.682761 after 16 iters
# MPB solved for frequency_1(2.09961,-0.0667051,0) = 0.645184 after 9 iters
# MPB solved for frequency_1(2.09953,-0.0667026,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.09953,-0.0667026,0) = 0.645161 after 1 iters
# MPB solved for frequency_1(2.23033,-0.141931,0) = 0.682951 after 16 iters
# MPB solved for frequency_1(2.09575,-0.133367,0) = 0.645184 after 9 iters
# MPB solved for frequency_1(2.09567,-0.133362,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.09567,-0.133362,0) = 0.645161 after 1 iters
# MPB solved for frequency_1(2.22468,-0.212896,0) = 0.683159 after 15 iters
# MPB solved for frequency_1(2.08969,-0.199978,0) = 0.645184 after 9 iters
# MPB solved for frequency_1(2.08961,-0.19997,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.08961,-0.19997,0) = 0.645161 after 1 iters
# MPB solved for frequency_1(2.21674,-0.283862,0) = 0.682887 after 14 iters
# MPB solved for frequency_1(2.08322,-0.266765,0) = 0.645183 after 8 iters
# MPB solved for frequency_1(2.08315,-0.266755,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.08315,-0.266755,0) = 0.645161 after 1 iters
# MPB solved for frequency_1(2.20649,-0.354827,0) = 0.683319 after 14 iters
# MPB solved for frequency_1(2.07205,-0.333207,0) = 0.645183 after 8 iters
# MPB solved for frequency_1(2.07197,-0.333195,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.07197,-0.333195,0) = 0.645161 after 1 iters
# MPB solved for frequency_1(2.1939,-0.425793,0) = 0.682554 after 15 iters
# MPB solved for frequency_1(2.06295,-0.400378,0) = 0.645182 after 9 iters
# MPB solved for frequency_1(2.06288,-0.400364,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.17893,-0.496758,0) = 0.682914 after 15 iters
# MPB solved for frequency_1(2.04761,-0.466819,0) = 0.645182 after 8 iters
# MPB solved for frequency_1(2.04753,-0.466802,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.16153,-0.567723,0) = 0.683055 after 17 iters
# MPB solved for frequency_1(2.03077,-0.53338,0) = 0.645182 after 9 iters
# MPB solved for frequency_1(2.0307,-0.533362,0) = 0.645161 after 3 iters
# MPB solved for frequency_1(2.14163,-0.638689,0) = 0.683719 after 17 iters
# MPB solved for frequency_1(2.00977,-0.599365,0) = 0.645182 after 9 iters
# MPB solved for frequency_1(2.0097,-0.599344,0) = 0.645161 after 4 iters
# MPB solved for frequency_1(2.11917,-0.709654,0) = 0.682815 after 16 iters
# MPB solved for frequency_1(1.99182,-0.667008,0) = 0.64518 after 8 iters
# MPB solved for frequency_1(1.99176,-0.666987,0) = 0.645161 after 3 iters

# %% [markdown]
# ### Run Simulation

# %%
# sim.run(until=300)

f = plt.figure(dpi=150)
sim.plot2D(fields=mp.Ez, 
           field_parameters={'alpha':0.9})
Animate = mp.Animate2D(fields=mp.Ez, f=f, realtime=False, normalize=True) 
sim.run(mp.at_every(0.5, Animate), until=50)
# until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, pt=mp.Vector3(x=5), decay_by=1e-2)
plt.show()
from IPython.display import Video

filename = "star_coupler.mp4"
fps = 10
Animate.to_mp4(fps, filename)
Video(filename)
# Out:
#      block, center = (0,0,0)
#           size (59.9875,37.4875,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (13.4473,-9.52625,0)
#           size (60,0.5,1e+20)
#           axes (0.948244,-0.317542,0), (0.317542,0.948244,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (13.7488,-8.57362,0)
#           size (60,0.5,1e+20)
#           axes (0.958293,-0.285787,0), (0.285787,0.958293,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.0159,-7.621,0)
#           size (60,0.5,1e+20)
#           axes (0.967195,-0.254033,0), (0.254033,0.967195,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.2495,-6.66837,0)
#           size (60,0.5,1e+20)
#           axes (0.974983,-0.222279,0), (0.222279,0.974983,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.4505,-5.71575,0)
#           size (60,0.5,1e+20)
#           axes (0.981682,-0.190525,0), (0.190525,0.981682,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.6195,-4.76312,0)
#           size (60,0.5,1e+20)
#           axes (0.987315,-0.158771,0), (0.158771,0.987315,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.757,-3.8105,0)
#           size (60,0.5,1e+20)
#           axes (0.991901,-0.127017,0), (0.127017,0.991901,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.8636,-2.85787,0)
#           size (60,0.5,1e+20)
#           axes (0.995452,-0.0952625,0), (0.0952625,0.995452,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.9394,-1.90525,0)
#           size (60,0.5,1e+20)
#           axes (0.997981,-0.0635083,0), (0.0635083,0.997981,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      ...(+ 33 objects not shown)...
# FloatProgress(value=0.0, description='0% done ', max=50.0)
#      block, center = (0,0,0)
#           size (59.9875,37.4875,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (13.4473,-9.52625,0)
#           size (60,0.5,1e+20)
#           axes (0.948244,-0.317542,0), (0.317542,0.948244,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (13.7488,-8.57362,0)
#           size (60,0.5,1e+20)
#           axes (0.958293,-0.285787,0), (0.285787,0.958293,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.0159,-7.621,0)
#           size (60,0.5,1e+20)
#           axes (0.967195,-0.254033,0), (0.254033,0.967195,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.2495,-6.66837,0)
#           size (60,0.5,1e+20)
#           axes (0.974983,-0.222279,0), (0.222279,0.974983,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.4505,-5.71575,0)
#           size (60,0.5,1e+20)
#           axes (0.981682,-0.190525,0), (0.190525,0.981682,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.6195,-4.76312,0)
#           size (60,0.5,1e+20)
#           axes (0.987315,-0.158771,0), (0.158771,0.987315,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.757,-3.8105,0)
#           size (60,0.5,1e+20)
#           axes (0.991901,-0.127017,0), (0.127017,0.991901,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.8636,-2.85787,0)
#           size (60,0.5,1e+20)
#           axes (0.995452,-0.0952625,0), (0.0952625,0.995452,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.9394,-1.90525,0)
#           size (60,0.5,1e+20)
#           axes (0.997981,-0.0635083,0), (0.0635083,0.997981,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      ...(+ 33 objects not shown)...
# Meep progress: 0.5/50.0 = 1.0% done in 13.4s, 1330.1s to go
# on time step 80 (time=0.5), 0.167932 s/step
# Meep progress: 1.0875000000000001/50.0 = 2.2% done in 17.5s, 785.1s to go
# on time step 174 (time=1.0875), 0.0427452 s/step
# Meep progress: 1.6625/50.0 = 3.3% done in 21.5s, 624.0s to go
# on time step 266 (time=1.6625), 0.0435613 s/step
# Meep progress: 2.325/50.0 = 4.7% done in 25.5s, 522.2s to go
# on time step 372 (time=2.325), 0.0377725 s/step
# Meep progress: 3.0/50.0 = 6.0% done in 29.9s, 469.0s to go
# on time step 480 (time=3), 0.0413736 s/step
# Meep progress: 3.575/50.0 = 7.2% done in 34.0s, 441.1s to go
# on time step 572 (time=3.575), 0.0438514 s/step
# Meep progress: 4.1937500000000005/50.0 = 8.4% done in 38.0s, 415.0s to go
# on time step 671 (time=4.19375), 0.0406551 s/step
# Meep progress: 4.8187500000000005/50.0 = 9.6% done in 42.0s, 393.9s to go
# on time step 771 (time=4.81875), 0.0401978 s/step
# Meep progress: 5.49375/50.0 = 11.0% done in 46.0s, 373.0s to go
# on time step 879 (time=5.49375), 0.037244 s/step
# Meep progress: 6.075/50.0 = 12.2% done in 50.0s, 361.8s to go
# on time step 972 (time=6.075), 0.0430278 s/step
# Meep progress: 6.706250000000001/50.0 = 13.4% done in 54.0s, 348.9s to go
# on time step 1073 (time=6.70625), 0.0396045 s/step
# Meep progress: 7.3375/50.0 = 14.7% done in 58.0s, 337.5s to go
# on time step 1174 (time=7.3375), 0.0396468 s/step
# Meep progress: 7.9750000000000005/50.0 = 16.0% done in 62.1s, 327.0s to go
# on time step 1276 (time=7.975), 0.0393007 s/step
# Meep progress: 8.543750000000001/50.0 = 17.1% done in 66.1s, 320.5s to go
# on time step 1367 (time=8.54375), 0.0439858 s/step
# Meep progress: 9.225/50.0 = 18.4% done in 70.1s, 309.7s to go
# on time step 1476 (time=9.225), 0.0368158 s/step
# Meep progress: 9.918750000000001/50.0 = 19.8% done in 74.1s, 299.4s to go
# on time step 1587 (time=9.91875), 0.0361769 s/step
# Meep progress: 10.5/50.0 = 21.0% done in 78.1s, 293.8s to go
# on time step 1680 (time=10.5), 0.0431983 s/step
# Meep progress: 11.09375/50.0 = 22.2% done in 82.1s, 288.0s to go
# on time step 1775 (time=11.0938), 0.0421575 s/step
# Meep progress: 11.725000000000001/50.0 = 23.5% done in 86.1s, 281.1s to go
# on time step 1876 (time=11.725), 0.0397441 s/step
# Meep progress: 12.33125/50.0 = 24.7% done in 90.1s, 275.4s to go
# on time step 1973 (time=12.3313), 0.0413791 s/step
# Meep progress: 12.96875/50.0 = 25.9% done in 94.2s, 268.9s to go
# on time step 2075 (time=12.9688), 0.0394346 s/step
# Meep progress: 13.525/50.0 = 27.1% done in 98.2s, 264.8s to go
# on time step 2164 (time=13.525), 0.0452004 s/step
# Meep progress: 14.15625/50.0 = 28.3% done in 102.2s, 258.8s to go
# on time step 2265 (time=14.1562), 0.0397753 s/step
# Meep progress: 14.76875/50.0 = 29.5% done in 106.2s, 253.4s to go
# on time step 2363 (time=14.7688), 0.0410157 s/step
# Meep progress: 15.387500000000001/50.0 = 30.8% done in 110.2s, 248.0s to go
# on time step 2462 (time=15.3875), 0.0405731 s/step
# Meep progress: 15.99375/50.0 = 32.0% done in 114.3s, 242.9s to go
# on time step 2559 (time=15.9938), 0.0414038 s/step
# Meep progress: 16.525000000000002/50.0 = 33.1% done in 118.3s, 239.6s to go
# on time step 2644 (time=16.525), 0.0471853 s/step
# Meep progress: 17.1375/50.0 = 34.3% done in 122.3s, 234.5s to go
# on time step 2742 (time=17.1375), 0.0409591 s/step
# Meep progress: 17.73125/50.0 = 35.5% done in 126.3s, 229.8s to go
# on time step 2837 (time=17.7312), 0.042192 s/step
# Meep progress: 18.306250000000002/50.0 = 36.6% done in 130.3s, 225.6s to go
# on time step 2929 (time=18.3063), 0.0434916 s/step
# Meep progress: 18.9375/50.0 = 37.9% done in 134.3s, 220.3s to go
# on time step 3030 (time=18.9375), 0.0398195 s/step
# Meep progress: 19.5/50.0 = 39.0% done in 138.5s, 216.6s to go
# on time step 3120 (time=19.5), 0.0460415 s/step
# Meep progress: 20.1/50.0 = 40.2% done in 142.5s, 212.0s to go
# on time step 3216 (time=20.1), 0.0419633 s/step
# Meep progress: 20.6875/50.0 = 41.4% done in 146.5s, 207.6s to go
# on time step 3310 (time=20.6875), 0.042645 s/step
# Meep progress: 21.275000000000002/50.0 = 42.6% done in 150.5s, 203.2s to go
# on time step 3404 (time=21.275), 0.0427441 s/step
# Meep progress: 21.88125/50.0 = 43.8% done in 154.5s, 198.6s to go
# on time step 3501 (time=21.8813), 0.0413437 s/step
# Meep progress: 22.5/50.0 = 45.0% done in 158.9s, 194.2s to go
# on time step 3600 (time=22.5), 0.0441259 s/step
# Meep progress: 23.08125/50.0 = 46.2% done in 162.9s, 190.0s to go
# on time step 3693 (time=23.0813), 0.0432181 s/step
# Meep progress: 23.69375/50.0 = 47.4% done in 166.9s, 185.3s to go
# on time step 3792 (time=23.7), 0.0407448 s/step
# Meep progress: 24.337500000000002/50.0 = 48.7% done in 170.9s, 180.3s to go
# on time step 3895 (time=24.3438), 0.0391182 s/step
# Meep progress: 24.931250000000002/50.0 = 49.9% done in 175.0s, 175.9s to go
# on time step 3990 (time=24.9375), 0.042408 s/step
# Meep progress: 25.5/50.0 = 51.0% done in 179.2s, 172.2s to go
# on time step 4080 (time=25.5), 0.0470233 s/step
# Meep progress: 26.1/50.0 = 52.2% done in 183.3s, 167.8s to go
# on time step 4176 (time=26.1), 0.0417784 s/step
# Meep progress: 26.650000000000002/50.0 = 53.3% done in 187.3s, 164.1s to go
# on time step 4264 (time=26.65), 0.0456929 s/step
# Meep progress: 27.2375/50.0 = 54.5% done in 191.3s, 159.9s to go
# on time step 4358 (time=27.2375), 0.0429003 s/step
# Meep progress: 27.89375/50.0 = 55.8% done in 195.3s, 154.8s to go
# on time step 4463 (time=27.8938), 0.0382146 s/step
# Meep progress: 28.481250000000003/50.0 = 57.0% done in 199.4s, 150.6s to go
# on time step 4557 (time=28.4813), 0.0428828 s/step
# Meep progress: 29.0/50.0 = 58.0% done in 203.4s, 147.3s to go
# on time step 4640 (time=29), 0.0490677 s/step
# Meep progress: 29.6125/50.0 = 59.2% done in 207.5s, 142.8s to go
# on time step 4738 (time=29.6125), 0.0411465 s/step
# Meep progress: 30.262500000000003/50.0 = 60.5% done in 211.5s, 137.9s to go
# on time step 4842 (time=30.2625), 0.0387398 s/step
# Meep progress: 30.89375/50.0 = 61.8% done in 215.5s, 133.3s to go
# on time step 4943 (time=30.8938), 0.0396931 s/step
# Meep progress: 31.5/50.0 = 63.0% done in 219.9s, 129.2s to go
# on time step 5040 (time=31.5), 0.045783 s/step
# Meep progress: 32.11875/50.0 = 64.2% done in 224.0s, 124.7s to go
# on time step 5139 (time=32.1187), 0.0405941 s/step
# Meep progress: 32.78125/50.0 = 65.6% done in 228.0s, 119.8s to go
# on time step 5245 (time=32.7812), 0.0379972 s/step
# Meep progress: 33.4375/50.0 = 66.9% done in 232.0s, 114.9s to go
# on time step 5350 (time=33.4375), 0.0381434 s/step
# Meep progress: 34.0/50.0 = 68.0% done in 236.3s, 111.2s to go
# on time step 5440 (time=34), 0.0476459 s/step
# Meep progress: 34.61875/50.0 = 69.2% done in 240.3s, 106.8s to go
# on time step 5539 (time=34.6187), 0.0404459 s/step
# Meep progress: 35.25/50.0 = 70.5% done in 244.3s, 102.2s to go
# on time step 5640 (time=35.25), 0.0398828 s/step
# Meep progress: 35.862500000000004/50.0 = 71.7% done in 248.3s, 97.9s to go
# on time step 5738 (time=35.8625), 0.0408395 s/step
# Meep progress: 36.5/50.0 = 73.0% done in 252.7s, 93.5s to go
# on time step 5840 (time=36.5), 0.0433884 s/step
# Meep progress: 37.1375/50.0 = 74.3% done in 256.7s, 88.9s to go
# on time step 5942 (time=37.1375), 0.0392534 s/step
# Meep progress: 37.7875/50.0 = 75.6% done in 260.7s, 84.3s to go
# on time step 6046 (time=37.7875), 0.0384724 s/step
# Meep progress: 38.431250000000006/50.0 = 76.9% done in 264.8s, 79.7s to go
# on time step 6149 (time=38.4313), 0.0389271 s/step
# Meep progress: 39.018750000000004/50.0 = 78.0% done in 268.8s, 75.6s to go
# on time step 6243 (time=39.0188), 0.0427735 s/step
# Meep progress: 39.6625/50.0 = 79.3% done in 272.8s, 71.1s to go
# on time step 6346 (time=39.6625), 0.0388895 s/step
# Meep progress: 40.29375/50.0 = 80.6% done in 276.8s, 66.7s to go
# on time step 6447 (time=40.2938), 0.0398733 s/step
# Meep progress: 40.925000000000004/50.0 = 81.9% done in 280.8s, 62.3s to go
# on time step 6548 (time=40.925), 0.0399032 s/step
# Meep progress: 41.5/50.0 = 83.0% done in 285.1s, 58.4s to go
# on time step 6640 (time=41.5), 0.0458095 s/step
# Meep progress: 42.1/50.0 = 84.2% done in 289.1s, 54.2s to go
# on time step 6736 (time=42.1), 0.0419549 s/step
# Meep progress: 42.6625/50.0 = 85.3% done in 293.1s, 50.4s to go
# on time step 6826 (time=42.6625), 0.0448358 s/step
# Meep progress: 43.268750000000004/50.0 = 86.5% done in 297.1s, 46.2s to go
# on time step 6923 (time=43.2688), 0.0413516 s/step
# Meep progress: 43.875/50.0 = 87.8% done in 301.2s, 42.0s to go
# on time step 7020 (time=43.875), 0.0415136 s/step
# Meep progress: 44.493750000000006/50.0 = 89.0% done in 305.2s, 37.8s to go
# on time step 7119 (time=44.4938), 0.0405956 s/step
# Meep progress: 45.0/50.0 = 90.0% done in 309.3s, 34.4s to go
# on time step 7200 (time=45), 0.0512621 s/step
# Meep progress: 45.6/50.0 = 91.2% done in 313.4s, 30.2s to go
# on time step 7296 (time=45.6), 0.0419821 s/step
# Meep progress: 46.225/50.0 = 92.5% done in 317.4s, 25.9s to go
# on time step 7396 (time=46.225), 0.0400428 s/step
# Meep progress: 46.85625/50.0 = 93.7% done in 321.4s, 21.6s to go
# on time step 7497 (time=46.8563), 0.0398559 s/step
# Meep progress: 47.493750000000006/50.0 = 95.0% done in 325.4s, 17.2s to go
# on time step 7599 (time=47.4938), 0.0393239 s/step
# Meep progress: 48.056250000000006/50.0 = 96.1% done in 329.4s, 13.3s to go
# on time step 7689 (time=48.0563), 0.0448273 s/step
# Meep progress: 48.7/50.0 = 97.4% done in 333.4s, 8.9s to go
# on time step 7792 (time=48.7), 0.0388652 s/step
# Meep progress: 49.35625/50.0 = 98.7% done in 337.5s, 4.4s to go
# on time step 7897 (time=49.3563), 0.0382709 s/step
# Meep progress: 49.993750000000006/50.0 = 100.0% done in 341.5s, 0.0s to go
# on time step 7999 (time=49.9938), 0.0392498 s/step
# Normalizing field data...
# run 0 finished at t = 50.0 (8000 timesteps)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Generating MP4...
# <video src="star_coupler.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### Visualize E-field

# %%
from matplotlib.backends.backend_pdf import PdfPages 


figure,axes = plt.subplots()

fig1 = sim.plot2D(ax=axes,output_plane=mp.Volume(center=mp.Vector3(), size=mp.Vector3(l,w,0)),
               fields=mp.Ez,
               field_parameters={'alpha':0.9})
# Out:
#      block, center = (0,0,0)
#           size (59.9875,37.4875,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (13.4473,-9.52625,0)
#           size (60,0.5,1e+20)
#           axes (0.948244,-0.317542,0), (0.317542,0.948244,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (13.7488,-8.57362,0)
#           size (60,0.5,1e+20)
#           axes (0.958293,-0.285787,0), (0.285787,0.958293,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.0159,-7.621,0)
#           size (60,0.5,1e+20)
#           axes (0.967195,-0.254033,0), (0.254033,0.967195,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.2495,-6.66837,0)
#           size (60,0.5,1e+20)
#           axes (0.974983,-0.222279,0), (0.222279,0.974983,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.4505,-5.71575,0)
#           size (60,0.5,1e+20)
#           axes (0.981682,-0.190525,0), (0.190525,0.981682,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.6195,-4.76312,0)
#           size (60,0.5,1e+20)
#           axes (0.987315,-0.158771,0), (0.158771,0.987315,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.757,-3.8105,0)
#           size (60,0.5,1e+20)
#           axes (0.991901,-0.127017,0), (0.127017,0.991901,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.8636,-2.85787,0)
#           size (60,0.5,1e+20)
#           axes (0.995452,-0.0952625,0), (0.0952625,0.995452,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (14.9394,-1.90525,0)
#           size (60,0.5,1e+20)
#           axes (0.997981,-0.0635083,0), (0.0635083,0.997981,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      ...(+ 33 objects not shown)...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print("Input Monitors:");
for i in range(len(input_monitors)):
     print(mp.get_fluxes(input_monitors[i]), " --> ", mp.get_fluxes(output_monitors[i]))


waveguides = []
for i in range(len(input_monitors)):
    waveguides.append(str(i))

input_flux = []
output_flux = []

total_input = 0
total_output = 0

for i in range(len(input_monitors)):
    input_flux.append(mp.get_fluxes(input_monitors[i])[0])
    total_input += mp.get_fluxes(input_monitors[i])[0]

    output_flux.append(mp.get_fluxes(output_monitors[i])[0])
    total_output += mp.get_fluxes(output_monitors[i])[0]


print("Total input: ", total_input)
print("Total output: ", total_output)
# Out:
# Input Monitors:
# [14.49548028935608]  -->  [3.399159384995035e-73]
# [14.361309174264356]  -->  [9.683067782037344e-156]
# [14.212541073180482]  -->  [8.519152183402819e-261]
# [14.007057390348109]  -->  [0.0]
# [13.928159308356385]  -->  [0.0]
# [13.767600601596035]  -->  [0.0]
# [13.662591892215643]  -->  [0.0]
# [13.625392213514601]  -->  [0.0]
# [13.531793894002982]  -->  [0.0]
# [13.506233418588636]  -->  [0.0]
# [14.190148575670777]  -->  [0.0]
# [13.50625888749929]  -->  [0.0]
# [13.531820304362912]  -->  [0.0]
# [13.62540816268373]  -->  [0.0]
# [13.66258812674259]  -->  [0.0]
# [13.767599427286676]  -->  [0.0]
# [13.928159350193463]  -->  [0.0]
# [14.007081224423665]  -->  [0.0]
# [14.212590161878836]  -->  [1.7839073275912512e-259]
# [14.361484971669272]  -->  [9.128777610273489e-155]
# [14.49587633096062]  -->  [1.3460982014908913e-72]
# Total input:  292.38717477879516
# Total output:  1.6860141399903949e-72

# %% [markdown]
# Bar Graphs for Flux

# %%
# Make a data definition
data_input = {'Input': input_flux}
df_input = pd.DataFrame(data_input,columns=['Input'], index = waveguides)

# Multiple bar chart
fig2 = df_input.plot.bar()
plt.title('Input Waveguide Flux Level')
plt.xlabel('Waveguide')
plt.ylabel('Flux')

# Display the plot
plt.show()


# Make a data definition
data_output = {'Output': output_flux}
df_output = pd.DataFrame(data_output,columns=['Output'], index = waveguides)

# Multiple bar chart
fig3 = df_output.plot.bar()
plt.title('Output Waveguide Flux Level')
plt.xlabel('Waveguide')
plt.ylabel('Flux')
# Display the plot
plt.show()

# Make a data definition
data_comparison = {
    'Input': input_flux,
    'Output': output_flux
    }
df_comparison = pd.DataFrame(data_comparison,columns=['Input','Output'], index = waveguides)

# Multiple bar chart
fig4 = df_comparison.plot.bar()
plt.title("Input Flux vs Ouput Flux for Simple Star Coupler")
plt.xlabel("Wave Guide Number")
plt.ylabel("Flux")

# Display the plot
plt.show()


p = PdfPages("output_graphs.pdf")
figs = [fig1, fig2, fig3, fig4]

fig1.set_title("Efficiency = " + (str)(100*(total_output/total_input)) + "%")
for fig in figs:
    fig.figure.savefig(p, format='pdf')

p.close()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### SAVING SIMULATION

# %% [markdown]
# sim2 = mp.load("")
